# %%
import pandas as pd
import glob
import os

# %% [markdown]
# # Creacion de taxis.parquet

# %% [markdown]
# Este archivo contiene el proceso llevado a cabo para la creacion del dataset de **taxis** que se empleara para el analisis. Estos datos fueron extraidos de la pagina oficial del NYC TLC

# %%
archivos_parquet = glob.glob(os.path.join('parquet/', 'yellow*.parquet'))

yellow_taxis = pd.concat([pd.read_parquet(archivo) for archivo in archivos_parquet])
yellow_taxis
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2023-09-01 00:15:37   2023-09-01 00:20:21              1.0
# 1               2  2023-09-01 00:18:40   2023-09-01 00:30:28              2.0
# 2               2  2023-09-01 00:35:01   2023-09-01 00:39:04              1.0
# 3               2  2023-09-01 00:45:45   2023-09-01 00:47:37              1.0
# 4               2  2023-09-01 00:01:23   2023-09-01 00:38:05              1.0
# ...           ...                  ...                   ...              ...
# 2979178         2  2024-08-31 23:22:27   2024-08-31 23:52:10              NaN
# 2979179         2  2024-08-31 23:46:00   2024-09-01 00:10:00              NaN
# 2979180         2  2024-08-31 23:41:20   2024-08-31 23:56:24              NaN
# 2979181         2  2024-08-31 23:20:50   2024-08-31 23:35:33              NaN
# 2979182         1  2024-08-31 23:24:04   2024-08-31 23:36:45              NaN
#
# ...

# %%
yellow_taxis.to_parquet('yellow_taxis.parquet')

# %%
archivos_parquet = glob.glob(os.path.join('parquet/', 'green*.parquet'))
green_taxis = pd.concat([pd.read_parquet(archivo) for archivo in archivos_parquet])
green_taxis.rename(columns={'lpep_pickup_datetime':'tpep_pickup_datetime', 'lpep_dropoff_datetime':'tpep_dropoff_datetime'},inplace=True)
green_taxis
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime store_and_fwd_flag  \
# 0             1  2023-09-01 00:08:04   2023-09-01 00:13:39                  N
# 1             1  2023-09-01 00:30:44   2023-09-01 00:39:30                  N
# 2             2  2023-09-01 00:14:39   2023-09-01 00:38:30                  N
# 3             2  2023-09-01 00:35:48   2023-09-01 00:56:48                  N
# 4             2  2023-09-01 00:32:03   2023-09-01 00:43:11                  N
# ...         ...                  ...                   ...                ...
# 51766         2  2024-08-31 20:58:00   2024-08-31 21:25:00               None
# 51767         2  2024-08-31 21:39:00   2024-08-31 21:56:00               None
# 51768         2  2024-08-31 22:59:00   2024-08-31 23:19:00               None
# 51769         2  2024-08-31 22:26:00   2024-08-31 22:42:00               None
# 51770         1  2024-08-31 23:28:00   2024-08-31 23:42:08               None
#
# ...

# %%
green_taxis.to_parquet('green_taxis.parquet')

# %%
yellow_taxis['type']='yellow'
green_taxis['type']='green'

# %%
taxis = pd.concat([yellow_taxis,green_taxis], ignore_index=True)
taxis
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                1  2023-09-01 00:15:37   2023-09-01 00:20:21
# 1                2  2023-09-01 00:18:40   2023-09-01 00:30:28
# 2                2  2023-09-01 00:35:01   2023-09-01 00:39:04
# 3                2  2023-09-01 00:45:45   2023-09-01 00:47:37
# 4                2  2023-09-01 00:01:23   2023-09-01 00:38:05
# ...            ...                  ...                   ...
# 40176766         2  2024-08-31 20:58:00   2024-08-31 21:25:00
# 40176767         2  2024-08-31 21:39:00   2024-08-31 21:56:00
# 40176768         2  2024-08-31 22:59:00   2024-08-31 23:19:00
# 40176769         2  2024-08-31 22:26:00   2024-08-31 22:42:00
# 40176770         1  2024-08-31 23:28:00   2024-08-31 23:42:08
#
#           passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                     1.0           0.80         1.0                  N
# 1                     2.0           2.34         1.0                  N
# ...

# %%
taxis.to_parquet('taxis.parquet')

# %%
# El que mas comprime pero no sirve pa ni chimba
# taxis.to_parquet('taxis_brotli.parquet', engine='pyarrow', compression='brotli', compression_level=11)
